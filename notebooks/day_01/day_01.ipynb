# %% [markdown]
# # Computational Workflows for biomedical data

# %% [markdown]
# Welcome to the course Computational Workflows for Biomedical Data. Over the next two weeks, you will learn how to leverage nf-core pipelines to analyze biomedical data and gain hands-on experience in creating your own pipelines, with a strong emphasis on Nextflow and nf-core.
#
# Course Structure:
#
# - Week 1: You will use a variety of nf-core pipelines to analyze a publicly available biomedical study.
# - Week 2: We will shift focus to learning the basics of Nextflow, enabling you to design and implement your own computational workflows.<br>
# - Final Project: The last couple of days, you will apply your knowledge to create a custom pipeline for analyzing biomedical data using Nextflow and the nf-core template.

# %% [markdown]
# ## Basics
#
# If you have not installed all required software, please do so now asap!
#
#
# If you already installed all software, please go on and start answering the questions in this notebook. If you have any questions, don't hesitate to approach us.

# %% [markdown]
# 1. What is nf-core?

# %% [markdown]
# a community led effort for open-source nextflow pipelines

# %% [markdown]
# 2. How many pipelines are there currently in nf-core?

# %% [markdown]
# 139

# %% [markdown]
# 3. Are there any non-bioinformatic pipelines in nf-core?

# %% [markdown]
# yes, e.g. rangeland (https://nf-co.re/rangeland/1.0.0/) for satellite image analysis

# %% [markdown]
# 4. Let's go back a couple of steps. What is a pipeline and what do we use it for?

# %% [markdown]
# a defined set of tools that work together to provide data analysis in a reproducible manner.

# %% [markdown]
# 5. Why do you think nf-core adheres to strict guidelines?

# %% [markdown]
# to ensure standardised pipelines which follow best practice and provide a consistent experience with quality standards for results

# %% [markdown]
# 6. What are the main features of nf-core pipelines?

# %% [markdown]
# permissible licencing, run using a single command, versioning, workflow specifity, reproducibility

# %% [markdown]
# ## Let's start using the pipelines

# %% [markdown]
# 1. Find the nf-core pipeline used to measure differential abundance of genes

# %%
# run the pipeline in a cell 
# to run bash in jupyter notebooks, simply use ! before the command
# e.g.

# !pwd


# For the tasks in the first week, please use the command line to run your commands and simply paste the commands you used in the respective cells!
# Out:
# /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_01

# %%
# run the pipeline in the test profile using docker containers
# make sure to specify the version you want to use (use the latest one)


# !nextflow run nf-core/differentialabundance -profile test,docker --outdir differential_out_01
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [voluminous_mclean] DSL2 - revision: 3dd360fed0 [master]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : master
#   runName                     : voluminous_mclean
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_01
#   workDir                     : /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /Users/patrick/.nextflow/assets/nf-core/differentialabundance
#   userName                    : patrick
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : differential_out_01
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (1)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (3)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (3)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (6)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 0 of 2
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (7)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [89/4df59d] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (7)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (7)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (7)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (10)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 0 of 1
# [d8/39f826] NFC…, target:hND6, blocking:]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (13)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [1e/b768a1] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [62/4bb102] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (13)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [1e/b768a1] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [62/4bb102] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (14)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [1e/b768a1] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [ab/bf5d71] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [62/4bb102] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [1e/b768a1] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [ab/bf5d71] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [95/5950d0] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [1e/b768a1] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [ab/bf5d71] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [95/5950d0] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [1e/b768a1] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [ab/bf5d71] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [95/5950d0] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [5c/1adf36] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [ab/bf5d71] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [62/4bb102] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [5c/1adf36] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [ab/bf5d71] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [62/4bb102] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [5c/1adf36] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ab/bf5d71] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [62/4bb102] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [37/595d14] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [5c/1adf36] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ab/bf5d71] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [62/4bb102] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [37/595d14] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [5c/1adf36] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ab/bf5d71] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [3f/a28a03] NFC…Cherry_hND6_sample_number) | 0 of 2
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [62/4bb102] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [37/595d14] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [5c/1adf36] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ab/bf5d71] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [0e/cd1ecd] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [95/5950d0] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [37/595d14] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [5c/1adf36] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ab/bf5d71] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [0e/cd1ecd] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [95/5950d0] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [37/595d14] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [5c/1adf36] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ab/bf5d71] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [0e/cd1ecd] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [95/5950d0] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [37/595d14] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [1c/8f5545] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [5c/1adf36] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ab/bf5d71] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [0e/cd1ecd] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [95/5950d0] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [37/595d14] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [1c/8f5545] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [5c/1adf36] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ab/bf5d71] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [0e/cd1ecd] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [95/5950d0] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [37/595d14] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [1c/8f5545] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE | 0 of 1
#
# executor >  local (21)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [5c/1adf36] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ab/bf5d71] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [0e/cd1ecd] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [95/5950d0] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [37/595d14] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [1c/8f5545] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [dd/ff74d5] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (21)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [5c/1adf36] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ab/bf5d71] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [0e/cd1ecd] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [95/5950d0] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [37/595d14] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [1c/8f5545] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [dd/ff74d5] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
#
# executor >  local (21)
# [71/37b30b] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3a/a9c387] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [26/1f4432] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [07/eb1bdc] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [fd/86e9f7] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8c/91449e] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [5c/1adf36] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ab/bf5d71] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [58/1368ea] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [1e/f31e63] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [0e/cd1ecd] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [8b/7600e8] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [95/5950d0] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [37/595d14] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [1c/8f5545] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [dd/ff74d5] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
# Completed at: 29-Sep-2025 12:44:22
# Duration    : 1m 32s
# CPU hours   : (a few seconds)
# Succeeded   : 21

# %%
# repeat the run. What did change?
# !nextflow run nf-core/differentialabundance -profile test,docker --outdir differential_out_02
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [modest_neumann] DSL2 - revision: 3dd360fed0 [master]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : master
#   runName                     : modest_neumann
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_01
#   workDir                     : /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /Users/patrick/.nextflow/assets/nf-core/differentialabundance
#   userName                    : patrick
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : differential_out_02
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (1)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (3)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (3)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (6)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [7d/5df4cd] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (7)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [7d/5df4cd] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (7)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (7)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (7)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (10)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 0 of 1
# [60/d9bb98] NFC…, blocking:sample_number]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (11)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 0 of 1
# [60/d9bb98] NFC…, blocking:sample_number]) | 1 of 2
# [84/c7a1f0] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (13)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [84/c7a1f0] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [58/28b04e] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [84/c7a1f0] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [58/28b04e] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [84/c7a1f0] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [58/28b04e] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [84/c7a1f0] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [58/28b04e] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [58/28b04e] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [58/28b04e] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [58/28b04e] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [94/a65924] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [58/28b04e] NFC…Cherry_hND6_sample_number) | 1 of 2
# [2c/c4e2b2] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [46/a5f096] NFC…Cherry_hND6_sample_number) | 0 of 2
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [58/28b04e] NFC…Cherry_hND6_sample_number) | 1 of 2
# [2c/c4e2b2] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [48/d5b34c] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [94/a65924] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [2c/c4e2b2] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [46/a5f096] NFC…Cherry_hND6_sample_number) | 1 of 2
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [94/a65924] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [2c/c4e2b2] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [48/d5b34c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [94/a65924] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [2c/c4e2b2] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [21/a2c212] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [48/d5b34c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [94/a65924] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [2c/c4e2b2] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [21/a2c212] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (21)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [48/d5b34c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [94/a65924] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [2c/c4e2b2] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [21/a2c212] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [7c/6e22e4] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (21)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [48/d5b34c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [94/a65924] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [2c/c4e2b2] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [21/a2c212] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [7c/6e22e4] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
#
# executor >  local (21)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [dd/381519] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [48/d5b34c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [94/a65924] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [2c/c4e2b2] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [21/a2c212] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [7c/6e22e4] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
# Completed at: 29-Sep-2025 13:37:13
# Duration    : 52m 48s
# CPU hours   : 1.7
# Succeeded   : 21

# %%
# now set -resume to the command. What did change?
# !nextflow run nf-core/differentialabundance -profile test,docker --outdir differential_out_02 -resume
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [pensive_plateau] DSL2 - revision: 3dd360fed0 [master]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : master
#   runName                     : pensive_plateau
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_01
#   workDir                     : /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /Users/patrick/.nextflow/assets/nf-core/differentialabundance
#   userName                    : patrick
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : differential_out_02
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [7d/5df4cd] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [7d/5df4cd] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [58/28b04e] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [7d/5df4cd] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [58/28b04e] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [76/b38704] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [7d/5df4cd] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [46/a5f096] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [58/28b04e] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [76/b38704] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [7d/5df4cd] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [46/a5f096] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [58/28b04e] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [76/b38704] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [21/a2c212] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [7c/6e22e4] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔
#
# executor >  local (1)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [7d/5df4cd] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [46/a5f096] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [58/28b04e] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [76/b38704] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [21/a2c212] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [7c/6e22e4] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔
#
# executor >  local (1)
# [69/ccc7af] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [46/d7d1f9] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f4/279336] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [c8/e8884a] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [86/3b7a6e] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [e7/19c661] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [7f/663b79] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [72/63edfc] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [7d/5df4cd] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [06/9ac537] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [46/a5f096] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [18/a15ada] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [58/28b04e] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [76/b38704] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [21/a2c212] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [7c/6e22e4] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔
# Completed at: 29-Sep-2025 13:48:24
# Duration    : 11m 6s
# CPU hours   : 1.7 (99.8% cached)
# Succeeded   : 1
# Cached      : 20

# %% [markdown]
# Check out the current directory. Next to the outdir you specified, what else has changed?

# %% [markdown]
# we have nextflow log files as .nextflow.log$N, a work directory, a .nextflow directory with cached files

# %%
# delete the work directory and run the pipeline again using -resume. What did change?
# !rm -rf work
# !nextflow run nf-core/differentialabundance -profile test,docker --outdir differential_out_02 -resume
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [thirsty_heisenberg] DSL2 - revision: 3dd360fed0 [master]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : master
#   runName                     : thirsty_heisenberg
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_01
#   workDir                     : /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /Users/patrick/.nextflow/assets/nf-core/differentialabundance
#   userName                    : patrick
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : differential_out_02
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (1)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (3)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (3)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (6)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [8b/e8ad28] NFC…Cherry_hND6_sample_number) | 0 of 2
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (7)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [8b/e8ad28] NFC…Cherry_hND6_sample_number) | 1 of 2
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (7)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (7)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (7)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (10)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [56/299f7e] NFC…, target:hND6, blocking:]) | 0 of 1
# [69/bf29c6] NFC…, blocking:sample_number]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (12)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [56/299f7e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/bf29c6] NFC…, blocking:sample_number]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [b6/c9b2c0] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [cd/7bab89] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (13)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [56/299f7e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bf/b35981] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [29/0f075e] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [b6/c9b2c0] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [cd/7bab89] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (14)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [56/299f7e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bf/b35981] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [29/0f075e] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [b6/c9b2c0] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [cd/7bab89] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [50/072468] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [56/299f7e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bf/b35981] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [29/0f075e] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [b6/c9b2c0] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [cd/7bab89] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [71/9a878f] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [56/299f7e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bf/b35981] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e6/0b6fa3] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [b6/c9b2c0] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [cd/7bab89] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [50/072468] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [56/299f7e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bf/b35981] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e6/0b6fa3] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [b6/c9b2c0] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [cd/7bab89] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [71/9a878f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [95/8d1ab8] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [56/299f7e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bf/b35981] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e6/0b6fa3] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [b6/c9b2c0] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [2b/e85c6a] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [cd/7bab89] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [71/9a878f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [95/8d1ab8] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [56/299f7e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bf/b35981] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e6/0b6fa3] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b6/c9b2c0] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [47/548cd4] NFC…Cherry_hND6_sample_number) | 0 of 2
# [cd/7bab89] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [71/9a878f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [95/8d1ab8] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [56/299f7e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bf/b35981] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e6/0b6fa3] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b6/c9b2c0] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [2b/e85c6a] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [cd/7bab89] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [71/9a878f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [95/8d1ab8] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [56/299f7e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bf/b35981] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e6/0b6fa3] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b6/c9b2c0] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [47/548cd4] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [cd/7bab89] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [71/9a878f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [95/8d1ab8] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [e1/9eb7ec] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [56/299f7e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bf/b35981] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e6/0b6fa3] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b6/c9b2c0] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [47/548cd4] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [cd/7bab89] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [71/9a878f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [95/8d1ab8] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [e1/9eb7ec] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [56/299f7e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bf/b35981] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e6/0b6fa3] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b6/c9b2c0] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [47/548cd4] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [cd/7bab89] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [71/9a878f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [95/8d1ab8] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [e1/9eb7ec] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (21)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [56/299f7e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bf/b35981] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e6/0b6fa3] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b6/c9b2c0] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [47/548cd4] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [cd/7bab89] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [71/9a878f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [95/8d1ab8] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [e1/9eb7ec] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [90/18f2f2] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (21)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [56/299f7e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bf/b35981] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e6/0b6fa3] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b6/c9b2c0] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [47/548cd4] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [cd/7bab89] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [71/9a878f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [95/8d1ab8] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [e1/9eb7ec] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [90/18f2f2] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
#
# executor >  local (21)
# [10/2a8c42] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [7a/ea7435] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [0c/f540c4] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [fc/59dd63] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [56/299f7e] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [bf/b35981] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e6/0b6fa3] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b6/c9b2c0] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [17/655cba] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [07/6bd53e] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [47/548cd4] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [cd/7bab89] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [71/9a878f] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [95/8d1ab8] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [e1/9eb7ec] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [90/18f2f2] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
# Completed at: 29-Sep-2025 13:49:53
# Duration    : 1m 27s
# CPU hours   : (a few seconds)
# Succeeded   : 21

# %% [markdown]
# What changed?

# %% [markdown]
# ## Lets look at the results

# %% [markdown]
# ### What is differential abundance analysis?

# %% [markdown]
# Give the most important plots from the report:

# %%
from IPython.display import Image

# %%
Image('differential_out_01/plots/differential/treatment_mCherry_hND6_/png/volcano.png')

# %%
Image('differential_out_01/plots/exploratory/treatment/png/boxplot.png')

# %% [markdown]
# Differential analysis investigates the change in RNA expression levels of samples between different treatment conditions allowing for investigation of biological effects caused by treatment.
