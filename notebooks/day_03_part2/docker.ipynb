# %% [markdown]
# # A short introduction to containerized software
#
# After spending time using nf-core pipelines to answer bioinformatic questions, we will focus on the processes that lie behind these pipelines now.
#
# Today, we will focus on containerization, namely via Docker.

# %% [markdown]
# 1. Check if Docker is installed.

# %%
from pre_commit.lang_base import basic_run_hook
# !docker info
# Out:
# Client: Docker Engine - Community
#  Version:    28.4.0
#  Context:    desktop-linux
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.9.11
#     Path:     /Users/patrick/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.28.0-desktop.1
#     Path:     /Users/patrick/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.4.29
#     Path:     /Users/patrick/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.39.4-desktop.1
#     Path:     /Users/patrick/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.42
#     Path:     /Users/patrick/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.2.0
#     Path:     /Users/patrick/.docker/cli-plugins/docker-desktop
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.31
#     Path:     /Users/patrick/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/patrick/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  v0.21.0
#     Path:     /Users/patrick/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.41
#     Path:     /Users/patrick/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/patrick/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.18.3
#     Path:     /Users/patrick/.docker/cli-plugins/docker-scout
#
# Server:
#  Containers: 2
#   Running: 0
#   Paused: 0
#   Stopped: 2
#  Images: 14
#  Server Version: 28.4.0
#  Storage Driver: overlayfs
#   driver-type: io.containerd.snapshotter.v1
#  Logging Driver: json-file
#  Cgroup Driver: cgroupfs
#  Cgroup Version: 2
#  Plugins:
#   Volume: local
#   Network: bridge host ipvlan macvlan null overlay
#   Log: awslogs fluentd gcplogs gelf journald json-file local splunk syslog
#  CDI spec directories:
#   /etc/cdi
#   /var/run/cdi
#  Swarm: inactive
#  Runtimes: io.containerd.runc.v2 runc
#  Default Runtime: runc
#  Init Binary: docker-init
#  containerd version: 05044ec0a9a75232cad458027ca83437aae3f4da
#  runc version: v1.2.5-0-g59923ef
#  init version: de40ad0
#  Security Options:
#   seccomp
#    Profile: builtin
#   cgroupns
#  Kernel Version: 6.10.14-linuxkit
#  Operating System: Docker Desktop
#  OSType: linux
#  Architecture: aarch64
#  CPUs: 11
#  Total Memory: 7.654GiB
#  Name: docker-desktop
#  ID: 2fbb9ef9-dbd8-4b62-832b-673d1cf5ef69
#  Docker Root Dir: /var/lib/docker
#  Debug Mode: false
#  HTTP Proxy: http.docker.internal:3128
#  HTTPS Proxy: http.docker.internal:3128
#  No Proxy: hubproxy.docker.internal
#  Labels:
#   com.docker.desktop.address=unix:///Users/patrick/Library/Containers/com.docker.docker/Data/docker-cli.sock
#  Experimental: false
#  Insecure Registries:
#   hubproxy.docker.internal:5555
#   ::1/128
#   127.0.0.0/8
#  Live Restore Enabled: false

# %% [markdown]
# ### What is a container?

# %% [markdown]
# ### Why do we use containers?

# %% [markdown]
# ### What is a docker image?

# %% [markdown]
# ### Let's run our first docker image:

# %% [markdown]
# ### Login to docker

# %%
# This you need to do on the command line directly

# %% [markdown]
# ### Run your first docker container

# %%
# !docker run hello-world
# Out:
# Unable to find image 'hello-world:latest' locally
# latest: Pulling from library/hello-world
#
# Digest: sha256:54e66cc1dd1fcb1c3c58bd8017914dbed8701e2d8c74d9262e26bd9cc1642d31
# Status: Downloaded newer image for hello-world:latest
#
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (arm64v8)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %% [markdown]
# ### Find the container ID

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE                                                                         COMMAND                  CREATED              STATUS                          PORTS     NAMES
# 025a1fb6b506   hello-world                                                                   "/hello"                 About a minute ago   Exited (0) About a minute ago             flamboyant_blackburn
# 50104af93baa   community.wave.seqera.io/library/cutadapt_trim-galore_pigz:a98edd405b34582d   "/usr/local/bin/_ent…"   3 hours ago          Exited (137) 3 hours ago                  nxf-inl6YRyBVLJytPCW8x8ebuJz
# 6a9fca9d4542   community.wave.seqera.io/library/cutadapt_trim-galore_pigz:a98edd405b34582d   "/usr/local/bin/_ent…"   3 hours ago          Exited (137) 3 hours ago                  nxf-wfwXYs6XdKzimPXLh5A8h3xR

# %% [markdown]
# ### Delete the container again, give prove its deleted

# %%
# !docker container rm 025a1fb6b506
# Out:
# 025a1fb6b506

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE                                                                         COMMAND                  CREATED       STATUS                     PORTS     NAMES
# 50104af93baa   community.wave.seqera.io/library/cutadapt_trim-galore_pigz:a98edd405b34582d   "/usr/local/bin/_ent…"   3 hours ago   Exited (137) 3 hours ago             nxf-inl6YRyBVLJytPCW8x8ebuJz
# 6a9fca9d4542   community.wave.seqera.io/library/cutadapt_trim-galore_pigz:a98edd405b34582d   "/usr/local/bin/_ent…"   3 hours ago   Exited (137) 3 hours ago             nxf-wfwXYs6XdKzimPXLh5A8h3xR

# %% [markdown]
# ### FASTQC is a very useful tool as you've learned last week. Let's try and run it from command line
#
# Link to the software: https://www.bioinformatics.babraham.ac.uk/projects/fastqc/

# %% [markdown]
# Please describe the steps you took to download and run the software for the example fastq file from last week below:

# %% [markdown]
# 1. `mamba install fastqc`
# 2. `mkdir fastqc_manual_out`
# 3. `fastqc day_02/fetch_out/fastq/*.fastq.gz -o fastqc_manual_out`

# %% [markdown]
# ### Very well, now let's try to make use of its docker container
#
# 1. create a container holding fastqc using seqera containers (https://seqera.io/containers/)
# 2. use the container to generate a fastqc html of the example fastq file

# %%
# pull the container
# !docker image pull community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29
# Out:
# 0.12.1--af7a5314d5015c29: Pulling from library/fastqc
#
# c6865366: Pulling fs layer
# Digest: sha256:b7f6caf359264cf86da901b0aa5f66735a6506fcfbf103c66db6987253ad44c1
# Status: Downloaded newer image for community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29
# community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29

# %%
# !ls -a "/Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_02/fetch_out/fastq/"
# Out:
# ls: cannot access '/Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_02/fetch_out/fastq/*': No such file or directory

# %%
# run the container and save the results to a new "fastqc_results" directory
# !docker run --rm -v "/Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_02/fetch_out/fastq":/data -v "$PWD/fastqc_results":/out b7f6caf35926 fastqc "/data/SRX19144488_SRR23195511_1.fastq.gz" -o /out
# Out:
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# application/gzip
# Started analysis of SRX19144488_SRR23195511_1.fastq.gz
# Approx 5% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 10% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 15% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 20% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 25% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 30% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 35% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 40% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 45% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 50% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 55% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 60% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 65% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 70% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 75% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 80% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 85% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 90% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 95% complete for SRX19144488_SRR23195511_1.fastq.gz
# Analysis complete for SRX19144488_SRR23195511_1.fastq.gz

# %% [markdown]
# ### Now that you know how to use a docker container, which approach was easier and which approach will be easier in the future?

# %% [markdown]
# if the software is already packaged through conda it is equally fast however with complicatet dependencies, especially of outdated software a reproducible docker container which can easily be pulled is much faster

# %% [markdown]
# ### What would you say, which approach is more reproducible?

# %% [markdown]
# the docker container

# %% [markdown]
# ### Compare the file to last weeks fastqc results, are they identical?
# ### Is the fastqc version identical?

# %% [markdown]
# The docker and manual fastqc results are identical
#
# versions are both 0.12.1

# %% [markdown]
# ## Dockerfiles
#
# We now used Docker containers and images directly to boost our research.
#
# Let's create our own toy Dockerfile including the "cowsay" tool (https://en.wikipedia.org/wiki/Cowsay)
#
# Hints:
# 1. Docker is Linux, so you need to know the apt-get command to install "cowsay"

# %%
# open the file "my_dockerfile" in a text editor

# %% [markdown]
# ### Explain the RUN and ENV lines you added to the file

# %%
# build the docker image
# !docker build -f my_dockerfile docker_container
# Out:
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.2s
# [+] Building 0.3s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
# [+] Building 0.5s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
# [+] Building 0.6s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
# [+] Building 0.7s (2/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
# [+] Building 0.8s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            0.1s
#  => => # Reading package lists...
# [+] Building 1.0s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            0.3s
#  => => # Reading package lists...
# [+] Building 1.0s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            0.3s
#  => => # Reading package lists...
# [+] Building 1.2s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            0.5s
#  => => # The following additional packages will be installed:
#  => => #   ca-certificates libbrotli1 libcurl4 libgdbm-compat4 libgdbm6 libldap
#  => => # -2.4-2
#  => => #   libldap-common libnghttp2-14 libperl5.32 libpsl5 librtmp1 libsasl2-2
#  => => #   libsasl2-modules libsasl2-modules-db libssh2-1 libtext-charwidth-per
#  => => # l
# [+] Building 1.4s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            0.7s
#  => => # dbm6
#  => => #   libldap-2.4-2 libldap-common libnghttp2-14 libperl5.32 libpsl5 librt
#  => => # mp1
#  => => #   libsasl2-2 libsasl2-modules libsasl2-modules-db libssh2-1
#  => => #   libtext-charwidth-perl netbase openssl perl perl-modules-5.32 public
#  => => # suffix
# [+] Building 1.4s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            0.7s
#  => => # suffix
#  => => # 0 upgraded, 23 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 1.6s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            0.9s
#  => => # suffix
#  => => # 0 upgraded, 23 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 1.7s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            1.0s
#  => => # suffix
#  => => # 0 upgraded, 23 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 1.9s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            1.2s
#  => => # suffix
#  => => # 0 upgraded, 23 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 2.0s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            1.3s
#  => => # suffix
#  => => # 0 upgraded, 23 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 2.2s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            1.5s
#  => => # suffix
#  => => # 0 upgraded, 23 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 2.3s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            1.6s
#  => => # suffix
#  => => # 0 upgraded, 23 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 2.5s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            1.8s
#  => => # suffix
#  => => # 0 upgraded, 23 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 2.6s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            1.9s
#  => => # suffix
#  => => # 0 upgraded, 23 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 2.8s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            2.1s
#  => => # suffix
#  => => # 0 upgraded, 23 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 2.8s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            2.1s
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
# [+] Building 2.9s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            2.3s
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
# [+] Building 3.0s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            2.3s
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
# [+] Building 3.1s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            2.5s
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
# [+] Building 3.1s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            2.5s
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
# [+] Building 3.3s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            2.6s
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
# [+] Building 3.4s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            2.8s
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
# [+] Building 3.6s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            2.9s
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
# [+] Building 3.7s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            3.1s
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
# [+] Building 3.9s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            3.2s
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
# [+] Building 4.0s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            3.4s
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
# [+] Building 4.2s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            3.5s
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
# [+] Building 4.3s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            3.7s
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
# [+] Building 4.4s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            3.8s
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl arm64 5.32.1-4+deb11u4 [293 kB]
# [+] Building 4.6s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            3.9s
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl arm64 5.32.1-4+deb11u4 [293 kB]
# [+] Building 4.6s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            4.0s
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl arm64 5.32.1-4+deb11u4 [293 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye/main arm64 netbase all 6.3
#  => => #  [19.9 kB]
# [+] Building 4.8s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            4.2s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl arm64 5.32.1-4+deb11u4 [293 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye/main arm64 netbase all 6.3
#  => => #  [19.9 kB]
#  => => # Get:7 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 openssl arm64 1.1.1w-0+deb11u3 [837 kB]
# [+] Building 5.0s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            4.3s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl arm64 5.32.1-4+deb11u4 [293 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye/main arm64 netbase all 6.3
#  => => #  [19.9 kB]
#  => => # Get:7 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 openssl arm64 1.1.1w-0+deb11u3 [837 kB]
# [+] Building 5.0s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            4.3s
#  => => # Get:6 http://deb.debian.org/debian bullseye/main arm64 netbase all 6.3
#  => => #  [19.9 kB]
#  => => # Get:7 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 openssl arm64 1.1.1w-0+deb11u3 [837 kB]
#  => => # Get:8 http://deb.debian.org/debian bullseye/main arm64 ca-certificates
#  => => #  all 20210119 [158 kB]
# [+] Building 5.1s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            4.4s
#  => => # Get:7 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 openssl arm64 1.1.1w-0+deb11u3 [837 kB]
#  => => # Get:8 http://deb.debian.org/debian bullseye/main arm64 ca-certificates
#  => => #  all 20210119 [158 kB]
#  => => # Get:9 http://deb.debian.org/debian bullseye/main arm64 libtext-charwid
#  => => # th-perl arm64 0.04-10+b1 [10.6 kB]
# [+] Building 5.2s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            4.6s
#  => => # Get:9 http://deb.debian.org/debian bullseye/main arm64 libtext-charwid
#  => => # th-perl arm64 0.04-10+b1 [10.6 kB]
#  => => # Get:10 http://deb.debian.org/debian bullseye/main arm64 cowsay all 3.0
#  => => # 3+dfsg2-8 [21.4 kB]
#  => => # Get:11 http://deb.debian.org/debian bullseye/main arm64 libbrotli1 arm
#  => => # 64 1.0.9-2+b2 [267 kB]
# [+] Building 5.4s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            4.7s
#  => => # Get:9 http://deb.debian.org/debian bullseye/main arm64 libtext-charwid
#  => => # th-perl arm64 0.04-10+b1 [10.6 kB]
#  => => # Get:10 http://deb.debian.org/debian bullseye/main arm64 cowsay all 3.0
#  => => # 3+dfsg2-8 [21.4 kB]
#  => => # Get:11 http://deb.debian.org/debian bullseye/main arm64 libbrotli1 arm
#  => => # 64 1.0.9-2+b2 [267 kB]
# [+] Building 5.5s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
# ...
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            9.6s
#  => => # Setting up libldap-2.4-2:arm64 (2.4.57+dfsg-3+deb11u1) ...
#  => => # Setting up ca-certificates (20210119) ...
#  => => # debconf: unable to initialize frontend: Dialog
#  => => # debconf: (TERM is not set, so the dialog frontend is not usable.)
#  => => # debconf: falling back to frontend: Readline
#  => => # Updating certificates in /etc/ssl/certs...
# [+] Building 10.3s (5/6)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            9.6s
#  => => # Setting up ca-certificates (20210119) ...
#  => => # debconf: unable to initialize frontend: Dialog
#  => => # debconf: (TERM is not set, so the dialog frontend is not usable.)
#  => => # debconf: falling back to frontend: Readline
#  => => # Updating certificates in /etc/ssl/certs...
#  => => # 129 added, 0 removed; done.
# [+] Building 10.5s (5/6)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            9.8s
#  => => # Setting up cowsay (3.03+dfsg2-8) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u13) ...
#  => => # Processing triggers for ca-certificates (20210119) ...
#  => => # Updating certificates in /etc/ssl/certs...
#  => => # 0 added, 0 removed; done.
#  => => # Running hooks in /etc/ca-certificates/update.d...
# [+] Building 10.7s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            9.9s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.2s
#
#
#
#
# [+] Building 10.8s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            9.9s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.3s
# [+] Building 11.0s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            9.9s
#  => exporting to image                                                     0.5s
#  => => exporting layers                                                    0.5s
# [+] Building 11.1s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            9.9s
#  => exporting to image                                                     0.6s
#  => => exporting layers                                                    0.6s
# [+] Building 11.3s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            9.9s
#  => exporting to image                                                     0.8s
#  => => exporting layers                                                    0.8s
# [+] Building 11.4s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            9.9s
#  => exporting to image                                                     0.9s
#  => => exporting layers                                                    0.9s
# [+] Building 11.6s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            9.9s
#  => exporting to image                                                     1.1s
#  => => exporting layers                                                    1.1s
# [+] Building 11.7s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            9.9s
#  => exporting to image                                                     1.1s
#  => => exporting layers                                                    1.1s
#  => => exporting manifest sha256:7f2abb9db19dd8b1712537368c993095580fa4d1  0.0s
# [+] Building 11.8s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            9.9s
#  => exporting to image                                                     1.3s
#  => => exporting layers                                                    1.1s
#  => => exporting manifest sha256:7f2abb9db19dd8b1712537368c993095580fa4d1  0.0s
#  => => exporting config sha256:a1f613eda4fc4433a400e99114c030419e8d5136ad  0.0s
#  => => exporting attestation manifest sha256:5518a5844e9da34824b5ddaba074  0.0s
#  => => exporting manifest list sha256:4154aeb46525044d6403632dadbac407ed0  0.0s
#  => => naming to moby-dangling@sha256:4154aeb46525044d6403632dadbac407ed0  0.0s
#  => => unpacking to moby-dangling@sha256:4154aeb46525044d6403632dadbac407  0.2s
# [+] Building 12.0s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            9.9s
#  => exporting to image                                                     1.4s
#  => => exporting layers                                                    1.1s
#  => => exporting manifest sha256:7f2abb9db19dd8b1712537368c993095580fa4d1  0.0s
#  => => exporting config sha256:a1f613eda4fc4433a400e99114c030419e8d5136ad  0.0s
#  => => exporting attestation manifest sha256:5518a5844e9da34824b5ddaba074  0.0s
#  => => exporting manifest list sha256:4154aeb46525044d6403632dadbac407ed0  0.0s
#  => => naming to moby-dangling@sha256:4154aeb46525044d6403632dadbac407ed0  0.0s
#  => => unpacking to moby-dangling@sha256:4154aeb46525044d6403632dadbac407  0.3s
# [+] Building 12.0s (7/7) FINISHED                          docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 831B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt update                                            0.0s
#  => [3/3] RUN apt-get --yes install curl cowsay                            9.9s
#  => exporting to image                                                     1.4s
#  => => exporting layers                                                    1.1s
#  => => exporting manifest sha256:7f2abb9db19dd8b1712537368c993095580fa4d1  0.0s
#  => => exporting config sha256:a1f613eda4fc4433a400e99114c030419e8d5136ad  0.0s
#  => => exporting attestation manifest sha256:5518a5844e9da34824b5ddaba074  0.0s
#  => => exporting manifest list sha256:4154aeb46525044d6403632dadbac407ed0  0.0s
#  => => naming to moby-dangling@sha256:4154aeb46525044d6403632dadbac407ed0  0.0s
#  => => unpacking to moby-dangling@sha256:4154aeb46525044d6403632dadbac407  0.3s

# %%
# make sure that the image has been built
# !docker images --all
# Out:
# REPOSITORY                                                   TAG                        IMAGE ID       CREATED          SIZE
# <none>                                                       <none>                     4154aeb46525   10 minutes ago   220MB
# hello-world                                                  latest                     54e66cc1dd1f   7 weeks ago      16.9kB
# community.wave.seqera.io/library/cutadapt_trim-galore_pigz   a98edd405b34582d           4e56e5205f5a   9 months ago     1.73GB
# community.wave.seqera.io/library/fastqc                      0.12.1--af7a5314d5015c29   b7f6caf35926   11 months ago    1.37GB
# quay.io/biocontainers/fq                                     0.12.0--h9ee0642_0         74b59572f1d0   14 months ago    20MB
# quay.io/biocontainers/r-shinyngs                             1.8.8--r43hdfd78af_0       e0de72408557   17 months ago    1.99GB
# quay.io/biocontainers/atlas-gene-annotation-manipulation     1.1.1--hdfd78af_0          099d0e113ec8   18 months ago    1.82GB
# quay.io/nf-core/ubuntu                                       20.04                      59e9d08d8dc1   2 years ago      110MB
# quay.io/biocontainers/fastqc                                 0.12.1--hdfd78af_0         e194048df39c   2 years ago      939MB
# quay.io/biocontainers/pandas                                 1.5.2                      cbb54fcf8730   2 years ago      493MB
# quay.io/biocontainers/gsea                                   4.3.2--hdfd78af_0          0010041fff53   2 years ago      849MB
# quay.io/biocontainers/r-base                                 4.2.1                      6721ee8bfba2   2 years ago      1.17GB
# quay.io/biocontainers/p7zip                                  16.02                      731aaeef376a   3 years ago      47.7MB
# quay.io/biocontainers/python                                 3.9--1                     d97d2b329b4e   4 years ago      275MB
# quay.io/biocontainers/gawk                                   5.1.0                      9d300f3d0a35   5 years ago      53.4MB
# quay.io/biocontainers/bioconductor-deseq2                    1.34.0--r41hc247a5b_3      c06884d353ef   55 years ago     452MB
# quay.io/biocontainers/wget                                   1.20.1                     7e5ba9e87a25   55 years ago     26.9MB

# %%
# run the docker file 
# !fortune | docker run -i 4154aeb46525 cowsay
# Out:
#  ______________________________________
# / If we do not change our direction we \
# | are likely to end up where we are    |
# \ headed.                              /
#  --------------------------------------
#         \   ^__^
#          \  (oo)\_______
#             (__)\       )\/\
#                 ||----w |
#                 ||     ||

# %% [markdown]
# ## Let's do some bioinformatics with the docker file and create a new docker file that holds the salmon tool used in rnaseq
#
# To do so, use "curl" in your new dockerfile to get salmon from https://github.com/COMBINE-lab/salmon/releases/download/v1.5.2/salmon-1.5.2_linux_x86_64.tar.gz

# %%
# use the file "salmon_docker" in this directory to build a new docker image
# file contents from salmon github dockerfile

# %%
# build the image
# !docker build --platform linux/amd64 -f salmon_docker . -t salmon_docker
# Out:
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.2s
# [+] Building 0.3s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.3s
# [+] Building 0.5s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
# [+] Building 0.5s (2/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
# [+] Building 0.6s (8/10)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.2s
# [+] Building 0.8s (8/10)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.3s
# [+] Building 0.9s (9/10)                                   docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
# [+] Building 1.0s (10/10)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
# [+] Building 1.1s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.2s
# [+] Building 1.3s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.3s
# [+] Building 1.4s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     0.5s
#  => => exporting layers                                                    0.5s
# [+] Building 1.6s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     0.6s
#  => => exporting layers                                                    0.6s
# [+] Building 1.7s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     0.8s
#  => => exporting layers                                                    0.8s
# [+] Building 1.9s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     0.9s
#  => => exporting layers                                                    0.9s
# [+] Building 2.0s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     1.1s
#  => => exporting layers                                                    1.1s
# [+] Building 2.2s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     1.2s
#  => => exporting layers                                                    1.2s
# [+] Building 2.3s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     1.4s
#  => => exporting layers                                                    1.4s
# [+] Building 2.5s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     1.5s
#  => => exporting layers                                                    1.5s
# [+] Building 2.6s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     1.7s
#  => => exporting layers                                                    1.7s
# [+] Building 2.8s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     1.8s
#  => => exporting layers                                                    1.8s
# [+] Building 2.9s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     2.0s
#  => => exporting layers                                                    2.0s
# [+] Building 3.1s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     2.1s
#  => => exporting layers                                                    2.1s
# [+] Building 3.2s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     2.3s
#  => => exporting layers                                                    2.3s
# [+] Building 3.4s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     2.4s
#  => => exporting layers                                                    2.4s
# [+] Building 3.5s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     2.6s
#  => => exporting layers                                                    2.6s
# [+] Building 3.7s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     2.7s
#  => => exporting layers                                                    2.7s
# [+] Building 3.8s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     2.9s
#  => => exporting layers                                                    2.9s
# [+] Building 4.0s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     3.0s
#  => => exporting layers                                                    3.0s
# [+] Building 4.1s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     3.2s
#  => => exporting layers                                                    3.2s
# [+] Building 4.3s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     3.3s
#  => => exporting layers                                                    3.3s
# [+] Building 4.4s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     3.5s
#  => => exporting layers                                                    3.5s
# [+] Building 4.6s (10/11)                                  docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     3.6s
#  => => exporting layers                                                    3.6s
#  => => exporting manifest sha256:0b07682d5b807583c0c8874e17115c5f3c231fc6  0.0s
# [+] Building 4.6s (11/11) FINISHED                         docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 753B                                       0.0s
#  => WARN: FromAsCasing: 'as' and 'FROM' keywords' casing do not match (li  0.0s
#  => [internal] load metadata for docker.io/library/ubuntu:18.04            0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/7] FROM docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => => resolve docker.io/library/ubuntu:18.04@sha256:152dc042452c496007f0  0.0s
#  => CACHED [2/7] RUN apt update                                            0.0s
#  => CACHED [3/7] RUN apt-get install --yes ca-certificates zlib1g-dev lib  0.0s
#  => CACHED [4/7] RUN curl -k -L  'https://github.com/COMBINE-lab/salmon/r  0.0s
#  => CACHED [5/7] RUN tar xf salmon.tar.gz                                  0.0s
#  => [6/7] RUN mv salmon-1.5.2_linux_x86_64/ /usr/bin/                      0.4s
#  => [7/7] RUN                                                              0.1s
#  => exporting to image                                                     3.6s
#  => => exporting layers                                                    3.6s
#  => => exporting manifest sha256:0b07682d5b807583c0c8874e17115c5f3c231fc6  0.0s
#  => => exporting config sha256:ce2db472039d73ee88548525ff23bffd1e3bfddd68  0.0s
#  => => exporting attestation manifest sha256:81536cd80bdd8bbb8d4b88af41ff  0.0s
#  => => exporting manifest list sha256:f7f6c58aee0aeb73aabcc3cf74f7a02ee66  0.0s
#  => => naming to docker.io/library/salmon_docker:latest                    0.0s
#
#  1 warning found (use docker --debug to expand):
#  - FromAsCasing: 'as' and 'FROM' keywords' casing do not match (line 1)

# %%
# run the docker image to give out the version of salmon
# !docker images --all
# Out:
# REPOSITORY                                                   TAG                        IMAGE ID       CREATED         SIZE
# salmon_docker                                                latest                     07a89e432efd   2 minutes ago   274MB
# <none>                                                       <none>                     594ba522afd9   19 hours ago    1.3GB
# <none>                                                       <none>                     4154aeb46525   20 hours ago    220MB
# hello-world                                                  latest                     54e66cc1dd1f   7 weeks ago     16.9kB
# community.wave.seqera.io/library/cutadapt_trim-galore_pigz   a98edd405b34582d           4e56e5205f5a   10 months ago   1.73GB
# community.wave.seqera.io/library/fastqc                      0.12.1--af7a5314d5015c29   b7f6caf35926   11 months ago   1.37GB
# quay.io/biocontainers/fq                                     0.12.0--h9ee0642_0         74b59572f1d0   15 months ago   20MB
# quay.io/biocontainers/r-shinyngs                             1.8.8--r43hdfd78af_0       e0de72408557   17 months ago   1.99GB
# quay.io/biocontainers/atlas-gene-annotation-manipulation     1.1.1--hdfd78af_0          099d0e113ec8   18 months ago   1.82GB
# quay.io/nf-core/ubuntu                                       20.04                      59e9d08d8dc1   2 years ago     110MB
# quay.io/biocontainers/fastqc                                 0.12.1--hdfd78af_0         e194048df39c   2 years ago     939MB
# quay.io/biocontainers/pandas                                 1.5.2                      cbb54fcf8730   2 years ago     493MB
# quay.io/biocontainers/gsea                                   4.3.2--hdfd78af_0          0010041fff53   2 years ago     849MB
# quay.io/biocontainers/r-base                                 4.2.1                      6721ee8bfba2   2 years ago     1.17GB
# quay.io/biocontainers/p7zip                                  16.02                      731aaeef376a   3 years ago     47.7MB
# quay.io/biocontainers/python                                 3.9--1                     d97d2b329b4e   4 years ago     275MB
# quay.io/biocontainers/gawk                                   5.1.0                      9d300f3d0a35   5 years ago     53.4MB
# quay.io/biocontainers/bioconductor-deseq2                    1.34.0--r41hc247a5b_3      c06884d353ef   55 years ago    452MB
# quay.io/biocontainers/wget                                   1.20.1                     7e5ba9e87a25   55 years ago    26.9MB

# %%
# !docker run --platform linux/amd64 salmon_docker salmon --version
# Out:
# salmon 1.5.2

# %% [markdown]
# ## Do you think bioinformaticians have to create a docker image every time they want to run a tool?
#
# Find the salmon docker image online and run it on your computer.
#
# combinelab/salmon, see output below
#
# What is https://biocontainers.pro/ ?
#
# community based containers for bioinformatics software based on conda docker and singularity. Provide ready to use collections of containerized tools.
#
# Ideally not if a container is already provided by the package developers

# %%
# !docker run --rm --platform linux/amd64 combinelab/salmon:latest salmon --version
# Out:
# salmon 1.10.3

# %% [markdown]
# ## Are there other ways to create Docker (or Apptainer) images?
#
# What is https://seqera.io/containers/ ?
