# %% [markdown]
# ## Great, now that we discussed a little let's continue

# %% [markdown]
# Given that the current approach utilized by the authors lacks reproducibility, we will explore an alternative method by leveraging nf-core pipelines for data analysis.
#
# Please explain, how we will achieve reproducibility for the course  with this approach.

# %% [markdown]
# specify parameters in a file with a constant run environment, constant tools

# %% [markdown]
# You have successfully downloaded 2 of the fastq files we will use in our study.
#
# What is the next step if we want to first have a count table and check the quality of our fastq files? What is the pipeline called to do so?

# %% [markdown]
# rna-seq

# %% [markdown]
# Analyze the 2 files using an nf-core pipeline.
#
# What does this pipeline do?
#
# Which are the main tools that will be used in the pipeline?

# %% [markdown]
# HISAT2 for alignment if we follow the previous paper, STAR-Salmon as default

# %% [markdown]
# As all other nf-core pipelines, the chosen pipeline takes in a samplesheet as input.
#
# Use Python and pandas to create the samplesheet for your 2 samples. Feel free to make use of the table you created earlier today.
#
# see part1 notebook
#
# Choose your sample names wisely, they must be the connection of the results to the metadata. If you can't find the sample in the metadata later, the analysis was useless.

# %%
# post here the command you used to run nf-core/rnaseq
# !nextflow run nf-core/rnaseq \
  --input sample_sheet.csv \
  --aligner hisat2 \
  --outdir results_rnaseq \
  -profile docker \
  --genome GRCm38 \
 -c nextflow.config
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/rnaseq` [mighty_banach] DSL2 - revision: 9738a2df42 [master]
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/rnaseq 3.21.0
# ------------------------------------------------------
# Input/output options
#   input              : sample_sheet.csv
#   outdir             : results_rnaseq
#
# Reference genome options
#   genome             : GRCm38
#   fasta              : s3://ngi-igenomes/igenomes//Mus_musculus/Ensembl/GRCm38/Sequence/WholeGenomeFasta/genome.fa
#   gtf                : s3://ngi-igenomes/igenomes//Mus_musculus/Ensembl/GRCm38/Annotation/Genes/genes.gtf
#   gene_bed           : s3://ngi-igenomes/igenomes//Mus_musculus/Ensembl/GRCm38/Annotation/Genes/genes.bed
#   star_index         : s3://ngi-igenomes/igenomes//Mus_musculus/Ensembl/GRCm38/Sequence/STARIndex/
#
# UMI options
#   umi_discard_read   : 0
#
# Alignment options
#   aligner            : hisat2
#
# Generic options
#   trace_report_suffix: 2025-09-30_14-57-08
#
# Core Nextflow options
#   revision           : master
#   runName            : mighty_banach
#   containerEngine    : docker
#   launchDir          : /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_02
#   workDir            : /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_02/work
#   projectDir         : /Users/patrick/.nextflow/assets/nf-core/rnaseq
#   userName           : patrick
#   profile            : docker
#   configFiles        : /Users/patrick/.nextflow/assets/nf-core/rnaseq/nextflow.config, /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_02/nextflow.config, /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_02/nextflow.config
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# * The pipeline
#     https://doi.org/10.5281/zenodo.1400710
#
# * The nf-core framework
#     https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#     https://github.com/nf-core/rnaseq/blob/master/CITATIONS.md
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…:HISAT2_EXTRACTSPLICESITES -
# [-        ] NFC…REPARE_GENOME:HISAT2_BUILD -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…:HISAT2_EXTRACTSPLICESITES -
# [-        ] NFC…REPARE_GENOME:HISAT2_BUILD -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…_ALIGN_HISAT2:HISAT2_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# Plus 5 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…:HISAT2_EXTRACTSPLICESITES -
# [-        ] NFC…REPARE_GENOME:HISAT2_BUILD -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…_ALIGN_HISAT2:HISAT2_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# Plus 23 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# executor >  local (2)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…:HISAT2_EXTRACTSPLICESITES -
# [-        ] NFC…REPARE_GENOME:HISAT2_BUILD -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [f6/972c9c] NFC…NESS:FQ_LINT (SRR23195516) | 0 of 2
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…_ALIGN_HISAT2:HISAT2_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# Plus 24 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# executor >  local (2)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…:HISAT2_EXTRACTSPLICESITES -
# [-        ] NFC…REPARE_GENOME:HISAT2_BUILD -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [f6/972c9c] NFC…NESS:FQ_LINT (SRR23195516) | 0 of 2
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…_ALIGN_HISAT2:HISAT2_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# Plus 24 more processes waiting for tasks…
# Staging foreign file: s3://ngi-igenomes/igenomes/Mus_musculus/Ensembl/GRCm38/Sequence/WholeGenomeFasta/genome.fa
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# executor >  local (2)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…:HISAT2_EXTRACTSPLICESITES -
# [-        ] NFC…REPARE_GENOME:HISAT2_BUILD -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [f6/972c9c] NFC…NESS:FQ_LINT (SRR23195516) | 0 of 2
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…_ALIGN_HISAT2:HISAT2_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# Plus 24 more processes waiting for tasks…
# Staging foreign file: s3://ngi-igenomes/igenomes/Mus_musculus/Ensembl/GRCm38/Sequence/WholeGenomeFasta/genome.fa
# Staging foreign file: s3://ngi-igenomes/igenomes/Mus_musculus/Ensembl/GRCm38/Annotation/Genes/genes.gtf
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# executor >  local (2)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…:HISAT2_EXTRACTSPLICESITES -
# [-        ] NFC…REPARE_GENOME:HISAT2_BUILD -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [f6/972c9c] NFC…NESS:FQ_LINT (SRR23195516) | 1 of 2
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC | 0 of 1
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE | 0 of 1
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…_ALIGN_HISAT2:HISAT2_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# Plus 24 more processes waiting for tasks…
#
#
#
# ERROR ~ Error executing process > 'NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FASTQ_FASTQC_UMITOOLS_TRIMGALORE:TRIMGALORE (SRR23195516)'
#
# Caused by:
#   Process requirement exceeds available CPUs -- req: 12; avail: 11
#
#
# Command executed:
#
#   [ ! -f  SRR23195516_trimmed_1.fastq.gz ] && ln -s SRX19144486_SRR23195516_1.fastq.gz SRR23195516_trimmed_1.fastq.gz
#   [ ! -f  SRR23195516_trimmed_2.fastq.gz ] && ln -s SRX19144486_SRR23195516_2.fastq.gz SRR23195516_trimmed_2.fastq.gz
#   trim_galore \
#       --fastqc_args '-t 12' \
#       --cores 8 \
#       --paired \
#       --gzip \
#       SRR23195516_trimmed_1.fastq.gz \
#       SRR23195516_trimmed_2.fastq.gz
#
#   cat <<-END_VERSIONS > versions.yml
#   "NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FASTQ_FASTQC_UMITOOLS_TRIMGALORE:TRIMGALORE":
#       trimgalore: $(echo $(trim_galore --version 2>&1) | sed 's/^.*version //; s/Last.*$//')
#       cutadapt: $(cutadapt --version)
#       pigz: $( pigz --version 2>&1 | sed 's/pigz //g' )
#   END_VERSIONS
#
# Command exit status:
#   -
#
# Command output:
#   (empty)
#
# Work dir:
#   /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_02/work/1e/a482c40f560b4aa9e22fbbefcbf7c3
#
# Container:
#   community.wave.seqera.io/library/cutadapt_trim-galore_pigz:a98edd405b34582d
#
# Tip: you can replicate the issue by changing to the process work dir and entering the command `bash .command.run`
#
#  -- Check '.nextflow.log' file for details
#
# executor >  local (2)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…:HISAT2_EXTRACTSPLICESITES -
# [-        ] NFC…REPARE_GENOME:HISAT2_BUILD -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [f6/972c9c] NFC…NESS:FQ_LINT (SRR23195516) | 1 of 2
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC | 0 of 1
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE | 0 of 1
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…_ALIGN_HISAT2:HISAT2_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# Plus 24 more processes waiting for tasks…
# Execution cancelled -- Finishing pending tasks before exit
# ERROR ~ Error executing process > 'NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FASTQ_FASTQC_UMITOOLS_TRIMGALORE:TRIMGALORE (SRR23195516)'
#
# Caused by:
#   Process requirement exceeds available CPUs -- req: 12; avail: 11
#
#
# Command executed:
#
#   [ ! -f  SRR23195516_trimmed_1.fastq.gz ] && ln -s SRX19144486_SRR23195516_1.fastq.gz SRR23195516_trimmed_1.fastq.gz
#   [ ! -f  SRR23195516_trimmed_2.fastq.gz ] && ln -s SRX19144486_SRR23195516_2.fastq.gz SRR23195516_trimmed_2.fastq.gz
#   trim_galore \
#       --fastqc_args '-t 12' \
#       --cores 8 \
#       --paired \
#       --gzip \
#       SRR23195516_trimmed_1.fastq.gz \
#       SRR23195516_trimmed_2.fastq.gz
#
#   cat <<-END_VERSIONS > versions.yml
#   "NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FASTQ_FASTQC_UMITOOLS_TRIMGALORE:TRIMGALORE":
#       trimgalore: $(echo $(trim_galore --version 2>&1) | sed 's/^.*version //; s/Last.*$//')
#       cutadapt: $(cutadapt --version)
#       pigz: $( pigz --version 2>&1 | sed 's/pigz //g' )
#   END_VERSIONS
#
# Command exit status:
#   -
#
# Command output:
#   (empty)
#
# Work dir:
#   /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_02/work/1e/a482c40f560b4aa9e22fbbefcbf7c3
#
# Container:
#   community.wave.seqera.io/library/cutadapt_trim-galore_pigz:a98edd405b34582d
#
# Tip: you can replicate the issue by changing to the process work dir and entering the command `bash .command.run`
#
#  -- Check '.nextflow.log' file for details
# ERROR ~ Pipeline failed. Please refer to troubleshooting docs: https://nf-co.re/docs/usage/troubleshooting
#
#  -- Check '.nextflow.log' file for details
#
# executor >  local (2)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…:HISAT2_EXTRACTSPLICESITES -
# [-        ] NFC…REPARE_GENOME:HISAT2_BUILD -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [f6/972c9c] NFC…NESS:FQ_LINT (SRR23195516) | 1 of 2
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC | 0 of 1
# [1e/a482c4] NFC…E:TRIMGALORE (SRR23195516) | 0 of 1
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…_ALIGN_HISAT2:HISAT2_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# Plus 24 more processes waiting for tasks…
# Execution cancelled -- Finishing pending tasks before exit
# ERROR ~ Error executing process > 'NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FASTQ_FASTQC_UMITOOLS_TRIMGALORE:TRIMGALORE (SRR23195516)'
#
# Caused by:
#   Process requirement exceeds available CPUs -- req: 12; avail: 11
#
#
# Command executed:
#
#   [ ! -f  SRR23195516_trimmed_1.fastq.gz ] && ln -s SRX19144486_SRR23195516_1.fastq.gz SRR23195516_trimmed_1.fastq.gz
#   [ ! -f  SRR23195516_trimmed_2.fastq.gz ] && ln -s SRX19144486_SRR23195516_2.fastq.gz SRR23195516_trimmed_2.fastq.gz
#   trim_galore \
#       --fastqc_args '-t 12' \
#       --cores 8 \
#       --paired \
#       --gzip \
#       SRR23195516_trimmed_1.fastq.gz \
#       SRR23195516_trimmed_2.fastq.gz
#
#   cat <<-END_VERSIONS > versions.yml
#   "NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FASTQ_FASTQC_UMITOOLS_TRIMGALORE:TRIMGALORE":
#       trimgalore: $(echo $(trim_galore --version 2>&1) | sed 's/^.*version //; s/Last.*$//')
#       cutadapt: $(cutadapt --version)
#       pigz: $( pigz --version 2>&1 | sed 's/pigz //g' )
#   END_VERSIONS
#
# Command exit status:
#   -
#
# Command output:
#   (empty)
#
# Work dir:
#   /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_02/work/1e/a482c40f560b4aa9e22fbbefcbf7c3
#
# Container:
#   community.wave.seqera.io/library/cutadapt_trim-galore_pigz:a98edd405b34582d
#
# Tip: you can replicate the issue by changing to the process work dir and entering the command `bash .command.run`
#
#  -- Check '.nextflow.log' file for details
# ERROR ~ Pipeline failed. Please refer to troubleshooting docs: https://nf-co.re/docs/usage/troubleshooting
#
#  -- Check '.nextflow.log' file for details
#
# executor >  local (2)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…:HISAT2_EXTRACTSPLICESITES -
# [-        ] NFC…REPARE_GENOME:HISAT2_BUILD -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [4c/8403e6] NFC…NESS:FQ_LINT (SRR23195511) | 2 of 2 ✔
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC | 0 of 1
# [1e/a482c4] NFC…E:TRIMGALORE (SRR23195516) | 0 of 1
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…_ALIGN_HISAT2:HISAT2_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# Plus 24 more processes waiting for tasks…
# Execution cancelled -- Finishing pending tasks before exit
# -[nf-core/rnaseq] Pipeline completed with errors-
# ERROR ~ Error executing process > 'NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FASTQ_FASTQC_UMITOOLS_TRIMGALORE:TRIMGALORE (SRR23195516)'
#
# Caused by:
#   Process requirement exceeds available CPUs -- req: 12; avail: 11
#
#
# Command executed:
#
#   [ ! -f  SRR23195516_trimmed_1.fastq.gz ] && ln -s SRX19144486_SRR23195516_1.fastq.gz SRR23195516_trimmed_1.fastq.gz
#   [ ! -f  SRR23195516_trimmed_2.fastq.gz ] && ln -s SRX19144486_SRR23195516_2.fastq.gz SRR23195516_trimmed_2.fastq.gz
#   trim_galore \
#       --fastqc_args '-t 12' \
#       --cores 8 \
#       --paired \
#       --gzip \
#       SRR23195516_trimmed_1.fastq.gz \
#       SRR23195516_trimmed_2.fastq.gz
#
#   cat <<-END_VERSIONS > versions.yml
#   "NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FASTQ_FASTQC_UMITOOLS_TRIMGALORE:TRIMGALORE":
#       trimgalore: $(echo $(trim_galore --version 2>&1) | sed 's/^.*version //; s/Last.*$//')
#       cutadapt: $(cutadapt --version)
#       pigz: $( pigz --version 2>&1 | sed 's/pigz //g' )
#   END_VERSIONS
#
# Command exit status:
#   -
#
# Command output:
#   (empty)
#
# Work dir:
#   /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_02/work/1e/a482c40f560b4aa9e22fbbefcbf7c3
#
# Container:
#   community.wave.seqera.io/library/cutadapt_trim-galore_pigz:a98edd405b34582d
#
# Tip: you can replicate the issue by changing to the process work dir and entering the command `bash .command.run`
#
#  -- Check '.nextflow.log' file for details
# ERROR ~ Pipeline failed. Please refer to troubleshooting docs: https://nf-co.re/docs/usage/troubleshooting
#
#  -- Check '.nextflow.log' file for details
#
# executor >  local (2)
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…:HISAT2_EXTRACTSPLICESITES -
# [-        ] NFC…REPARE_GENOME:HISAT2_BUILD -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [4c/8403e6] NFC…NESS:FQ_LINT (SRR23195511) | 2 of 2 ✔
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC | 0 of 1
# [1e/a482c4] NFC…E:TRIMGALORE (SRR23195516) | 0 of 1
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…_ALIGN_HISAT2:HISAT2_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_FLAGSTAT -
# [-        ] NFC…SAMTOOLS:SAMTOOLS_IDXSTATS -
# Plus 24 more processes waiting for tasks…
# Execution cancelled -- Finishing pending tasks before exit
# -[nf-core/rnaseq] Pipeline completed with errors-
# ERROR ~ Error executing process > 'NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FASTQ_FASTQC_UMITOOLS_TRIMGALORE:TRIMGALORE (SRR23195516)'
#
# Caused by:
#   Process requirement exceeds available CPUs -- req: 12; avail: 11
#
#
# Command executed:
#
#   [ ! -f  SRR23195516_trimmed_1.fastq.gz ] && ln -s SRX19144486_SRR23195516_1.fastq.gz SRR23195516_trimmed_1.fastq.gz
#   [ ! -f  SRR23195516_trimmed_2.fastq.gz ] && ln -s SRX19144486_SRR23195516_2.fastq.gz SRR23195516_trimmed_2.fastq.gz
#   trim_galore \
#       --fastqc_args '-t 12' \
#       --cores 8 \
#       --paired \
#       --gzip \
#       SRR23195516_trimmed_1.fastq.gz \
#       SRR23195516_trimmed_2.fastq.gz
#
#   cat <<-END_VERSIONS > versions.yml
#   "NFCORE_RNASEQ:RNASEQ:FASTQ_QC_TRIM_FILTER_SETSTRANDEDNESS:FASTQ_FASTQC_UMITOOLS_TRIMGALORE:TRIMGALORE":
#       trimgalore: $(echo $(trim_galore --version 2>&1) | sed 's/^.*version //; s/Last.*$//')
#       cutadapt: $(cutadapt --version)
#       pigz: $( pigz --version 2>&1 | sed 's/pigz //g' )
#   END_VERSIONS
#
# Command exit status:
#   -
#
# Command output:
#   (empty)
#
# Work dir:
#   /Users/patrick/Studium_Local/3.Sem/computational-workflows-2025/notebooks/day_02/work/1e/a482c40f560b4aa9e22fbbefcbf7c3
#
# Container:
#   community.wave.seqera.io/library/cutadapt_trim-galore_pigz:a98edd405b34582d
#
# Tip: you can replicate the issue by changing to the process work dir and entering the command `bash .command.run`
#
#  -- Check '.nextflow.log' file for details
# ERROR ~ Pipeline failed. Please refer to troubleshooting docs: https://nf-co.re/docs/usage/troubleshooting
#
#  -- Check '.nextflow.log' file for details
# Waiting for file transfers to complete (2 files)
# ERROR ~ Pipeline failed. Please refer to troubleshooting docs: https://nf-co.re/docs/usage/troubleshooting
#
#  -- Check '.nextflow.log' file for details

# %% [markdown]
# Explain all the parameters you set and why you set them in this way.

# %% [markdown]
# use docker profile, use hisat2 as in paper, genome is ensembl id of mouse reference genome, -c nextflow.config was an attempt to limit system resources as this workflow asks for 36GB memory but it keeps erroring out regardless

# %% [markdown]
# ## Browsing the results

# %% [markdown]
# How did the pipeline perform?

# %% [markdown]
# it did not due to system limitations

# %% [markdown]
# Explain the quality control steps. Are you happy with the quality and why. If not, why not.
# Please give additional information on :
# - ribosomal rRNA
# - Duplication
# - GC content
#
# What are the possible steps that could lead to poorer results?

# %% [markdown]
# Would you exclude any samples? If yes, which and why?

# %% [markdown]
# What would you now do to continue the experiment? What are the scientists trying to figure out? Which packages on R or python would you use?

# %% [markdown]
# deseq2
